# %% [markdown]
# # Modeling Calcium Dynamics for Myoepithelial Cells in Hydra¶

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
from imp import reload
from scipy.integrate import odeint
import functions
import plot_results
from functions import *

# %% [markdown]
# ## Time Stepping

# %%
# initial conditions
t = np.linspace(0, T, int(T/dt))
y0 = [c0, ct0, h0, ip0, v0, n0, m0, hh0]

# integrate
sol = odeint(rhs22, y0, t, hmax = 0.005)

c = sol[:, 0]
c_t = sol[:, 1]
h = sol[:, 2]
ip = sol[:, 3]
v = sol[:, 4]
n = sol[:, 5]
m = sol[:, 6]
hh = sol[:, 7]

# %% [markdown]
# ## Plot Results

# %%
plot_results.plot(TIME, c, c_t, ip, h, v)

# %%
plt.plot(j_vgcc(v))

# %%
aa = np.linspace(-100,40,10000)

# %%
def j_vgcc1(v, g_ca1, v_ca11, v_ca21, r_ca1):
    '''current through voltage-gated calcium channel'''
    return g_ca1 * (v-v_ca11) / (1 + np.exp(-(v-v_ca21) / r_ca1))

# %%
plt.figure()
plt.plot(aa, j_vgcc1(aa, g_ca, v_ca1, -24, r_ca))
plt.plot(aa, j_vgcc1(aa, g_ca, 100, -50, 5))

# %%
plt.plot(ip)

# %%
plt.plot(j_ip3r(c, c_t, h, ip))

# %%
j_vgcc_test=0.05 * (v0-v_ca1) / (1 + np.exp(-(v0-v_ca2) / r_ca))

# %%
j_vgcc_test
# Out:
# -0.06578963311087481

# %%
2*j_vgcc_test/v_l
# Out:
# -0.43859755407249873
