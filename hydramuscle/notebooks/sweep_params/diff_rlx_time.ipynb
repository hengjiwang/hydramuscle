# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

import hydramuscle.utils.utils as utils

# %%
lengths_1 = utils.length_of_model("../../results/data/length/coords_rlx50.txt", display=False)
lengths_2 = utils.length_of_model("../../results/data/length/coords_rlx100.txt", display=False)
lengths_3 = utils.length_of_model("../../results/data/length/coords_rlx200.txt", display=False)
lengths_4 = utils.length_of_model("../../results/data/length/coords_rlx500.txt", display=False)
lengths_5 = utils.length_of_model("../../results/data/length/coords_rlx1000.txt", display=False)

# %%
plt.figure(figsize=(10,5))
time_axis = np.arange(0, 100.1, 0.1)
plt.plot(time_axis, lengths_1, linewidth=3, label='relax_time=50s')
plt.plot(time_axis, lengths_2, linewidth=3, label='relax_time=100s')
plt.plot(time_axis, lengths_3, linewidth=3, label='relax_time=200s')
plt.plot(time_axis, lengths_4, linewidth=3, label='relax_time=500s')
plt.plot(time_axis, lengths_5, linewidth=3, label='relax_time=1000s')
plt.legend()
plt.grid()
plt.xlabel('time(s)')
plt.ylabel('length(mm)')
plt.show()
