# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.abspath(''), '..')))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import hydra.model.helper as helper
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Load model length data
lengths_1 = helper.length_of_model("./results/data/length/coords_520471_c03n0015_100-200.txt", display=False, totaltime=100)
lengths_2 = helper.length_of_model("./results/data/length/coords_520471_c03n0015_200-300.txt", display=False, totaltime=100)
lengths_3 = helper.length_of_model("./results/data/length/coords_520471_c03n0015_300-400.txt", display=False, totaltime=100)
lengths_4 = helper.length_of_model("./results/data/length/coords_520471_c03n0015_400-500.txt", display=False, totaltime=100)
lengths_5 = helper.length_of_model("./results/data/length/coords_520471_c03n0015_500-600.txt", display=False, totaltime=100)

# %%
lengths = lengths_1 + lengths_2 + lengths_3 + lengths_4 + lengths_5

# %%
real_lengths = pd.read_csv("./results/data/length/lengths_Pre_Bisect_40x_4fps_ex3.csv").values
real_lengths = [x*(0.227/40) for x in real_lengths]
real_lengths_filtered = helper.filter_abnormal(real_lengths)
real_lengths_filtered = real_lengths_filtered[1100:3040]

# %%
plt.figure(figsize=(20,3))
plt.plot(np.arange(0, 500, 0.1), lengths)
plt.plot(np.arange(0, 485, 0.25), real_lengths_filtered)

plt.show()
