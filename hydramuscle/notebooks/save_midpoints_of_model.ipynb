# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import hydramuscle.utils.utils as utils

# %%
lengths, midpoints = utils.length_of_model("../results/data/length/coords_chalf_endo_1.txt", totaltime=100, ret_midpts=True, display=False)
midpoints = midpoints[:, :, 1:3]
midpoints = midpoints.reshape(-1, 42)

# %%
dt = 0.1
plt.figure(figsize=(10,3))
start = 0
end = 990
plt.plot(np.arange(0, len(lengths[start:end]) * 0.1, 0.1), lengths[start:end])
plt.show()

# %%
df = pd.DataFrame(midpoints)
df.to_csv("./results/data/midpoints/midpoints_658838_c4n3.csv", index=False)
