# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.abspath(''), '..')))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import hydra.model.helper as helper

# %%
lengths, midpoints = helper.length_of_model("./results/data/length/coords_658838_c4n3.txt", totaltime=250, ret_midpts=True)
midpoints = midpoints[:,:,1:3]
midpoints = midpoints.reshape(2501, 42)

# %%
df = pd.DataFrame(midpoints)
df.to_csv("./results/data/midpoints/midpoints_658838_c4n3.csv", index=False)
