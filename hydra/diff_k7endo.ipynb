# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.abspath(''), '..')))

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

import hydra.model.helper as helper

# %%
lengths_1 = helper.length_of_model("./results/data/length/coords_k7endo_0005.txt", display=False)
lengths_2 = helper.length_of_model("./results/data/length/coords_k7endo_01.txt", display=False)
lengths_3 = helper.length_of_model("./results/data/length/coords_k7endo_0015.txt", display=False)
lengths_4 = helper.length_of_model("./results/data/length/coords_k7endo_005.txt", display=False)
lengths_5 = helper.length_of_model("./results/data/length/coords_k7endo_0075.txt", display=False)
lengths_6 = helper.length_of_model("./results/data/length/coords_k7endo_003.txt", display=False)
lengths_7 = helper.length_of_model("./results/data/length/coords_k7endo_001.txt", display=False)
lengths_8 = helper.length_of_model("./results/data/length/coords_k7endo_015.txt", display=False)
lengths_9 = helper.length_of_model("./results/data/length/coords_passive.txt", display=False)

# %%
plt.figure(figsize=(10,5))
time_axis = np.arange(0, 100.1, 0.1)
plt.plot(time_axis, lengths_1, linewidth=3, label='k7(endo)=0.005')
plt.plot(time_axis, lengths_7, linewidth=3, label='k7(endo)=0.01')
plt.plot(time_axis, lengths_3, linewidth=3, label='k7(endo)=0.015')
plt.plot(time_axis, lengths_6, linewidth=3, label='k7(endo)=0.03')
plt.plot(time_axis, lengths_4, linewidth=3, label='k7(endo)=0.05')
plt.plot(time_axis, lengths_5, linewidth=3, label='k7(endo)=0.075')
plt.plot(time_axis, lengths_2, linewidth=3, label='k7(endo)=0.1')
plt.plot(time_axis, lengths_8, linewidth=3, label='k7(endo)=0.15')
plt.plot(time_axis, lengths_9, linewidth=3, label='k7(endo)=0.15, $c_{half}$(endo)=0.5', linestyle='--', color='k')
plt.grid()
plt.legend()
plt.xlabel('time(s)')
plt.ylabel('length(mm)')
plt.show()
