# %% [markdown]
# # Modeling Calcium Dynamics for Myoepithelial Cells in Hydra¶

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
from imp import reload
from scipy.integrate import odeint
import functions
import plot_results
from functions import *

# %% [markdown]
# ## Time Stepping

# %%
# initial conditions
t = np.linspace(0, T, int(T/dt))
y0 = [c0, ct0, h0, ip0, v0, n0, m0, hh0]

# integrate
sol = odeint(rhs22, y0, t, hmax = 0.005)

c = sol[:, 0]
c_t = sol[:, 1]
h = sol[:, 2]
ip = sol[:, 3]
v = sol[:, 4]
n = sol[:, 5]
m = sol[:, 6]
hh = sol[:, 7]

# %% [markdown]
# ## Plot Results

# %%
plot_results.plot(TIME, c, c_t, ip, h, v)

# %%
alpha_n(-65.15) * (1 - n0) - beta_n(-65.15) * n0
# Out:
# 0.0009842876650872703

# %%
hh[-1]
# Out:
# 0.5960957200408543
