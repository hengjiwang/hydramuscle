# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.abspath(''), '..')))

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import hydra.model.helper as helper

# %%
# # Load model length data

# PREFIX = 'coords_349650_k3_16_k4_4_chalf_085_rlx_50_c11n1_'
# # PREFIX = 'coords_156006_k3_16_k4_4_chalf_085_c1n1_'
# # PREFIX = 'coords_156006_k7_075_0005_rlx_30_c075n1_'
# # PREFIX = 'coords_349650_k3_8_k4_2_c1n1_100-350'
# # PREFIX = 'coords_579123'


# lengths_1 = helper.length_of_model("./results/data/length/"+PREFIX+"100-350.txt", display=False, totaltime=100)
# lengths_2 = helper.length_of_model("./results/data/length/"+PREFIX+"350-500.txt", display=False, totaltime=100)

# %%
# lengths = lengths_1 + lengths_2 #  + lengths_3 + lengths_4 # + lengths_5
# # lengths = helper.length_of_model("./results/data/length/"+PREFIX+".txt", display=False, totaltime=100)

# %%
PREFIX = 'coords_156006_k7_075_0005_rlx_20_c075n1_'
lengths_1 = helper.length_of_model("./results/data/length/"+PREFIX+"100-350.txt", display=False, totaltime=100)
lengths_2 = helper.length_of_model("./results/data/length/"+PREFIX+"350-500.txt", display=False, totaltime=100)
lengths = lengths_1 + lengths_2
real_lengths = pd.read_csv("./results/data/length/lengths_Control-EGCaMP_exp1_a1_30x10fps_5%.csv").values
real_lengths = [x*(0.227/30) for x in real_lengths]
real_lengths_filtered = helper.filter_abnormal(real_lengths)
real_lengths_filtered = real_lengths_filtered[400:4000]
plt.figure(figsize=(20,4))
plt.plot(np.arange(0, 360, 0.1), real_lengths_filtered, linewidth=3, color='r')
plt.plot(np.arange(0, 400, 0.1), lengths, linewidth=3, color='b')
plt.show()

# %%
# PREFIX = 'coords_156006_k3_16_k4_4_chalf_085_c15n1_'
PREFIX = 'coords_156006_k3_16_k4_4_chalf_085_c165n1_scale0165_'
lengths_1 = helper.length_of_model("./results/data/length/"+PREFIX+"100-350.txt", display=False, totaltime=100)
lengths_2 = helper.length_of_model("./results/data/length/"+PREFIX+"350-500.txt", display=False, totaltime=100)
lengths = lengths_1 + lengths_2
real_lengths = pd.read_csv("./results/data/length/lengths_Control-EGCaMP_exp1_a1_30x10fps_5%.csv").values
real_lengths = [x*(0.227/30) for x in real_lengths]
real_lengths_filtered = helper.filter_abnormal(real_lengths)
real_lengths_filtered = real_lengths_filtered[417:4017]
plt.figure(figsize=(20,4))
plt.plot(np.arange(0, 360, 0.1), real_lengths_filtered, linewidth=3, color='r')
plt.plot(np.arange(0, 400, 0.1), lengths, linewidth=3, color='b')
# plt.ylim(0.5,0.7)
plt.show()

# %%
# PREFIX = 'coords_156006_k3_16_k4_4_chalf_085_c15n1_'
PREFIX = 'coords_728521_rlx60_'
lengths_1 = helper.length_of_model("./results/data/length/"+PREFIX+"100-350.txt", display=False, totaltime=100)
lengths_2 = helper.length_of_model("./results/data/length/"+PREFIX+"350-500.txt", display=False, totaltime=100)
lengths = lengths_1 + lengths_2
real_lengths = pd.read_csv("./results/data/length/lengths_Control-EGCaMP_exp1_a1_30x10fps_5%.csv").values
real_lengths = [x*(0.227/30) for x in real_lengths]
real_lengths_filtered = helper.filter_abnormal(real_lengths)
real_lengths_filtered = real_lengths_filtered[417:4017]
plt.figure(figsize=(20,4))
plt.plot(np.arange(0, 360, 0.1), real_lengths_filtered, linewidth=3, color='r')
plt.plot(np.arange(0, 400, 0.1), lengths, linewidth=3, color='b')
# plt.ylim(0.5,0.7)
plt.show()

# %%
PREFIX = 'coords_349650_k3_16_k4_4_chalf_085_rlx_50_c11n1_'
lengths_1 = helper.length_of_model("./results/data/length/"+PREFIX+"100-350.txt", display=False, totaltime=100)
lengths_2 = helper.length_of_model("./results/data/length/"+PREFIX+"350-600.txt", display=False, totaltime=100)
lengths = lengths_1 + lengths_2
real_lengths = pd.read_csv("./results/data/length/lengths_Pre_Bisect_40x_4fps_ex3.csv").values
real_lengths = [x*(0.227/40) for x in real_lengths]
real_lengths_filtered = helper.filter_abnormal(real_lengths)
real_lengths_filtered = real_lengths_filtered[1100:3040]
plt.figure(figsize=(20,4))
plt.plot(np.arange(0, 485, 0.25), real_lengths_filtered, linewidth=3, color='r')
plt.plot(np.arange(0, 500, 0.1), lengths, linewidth=3, color='b')
plt.show()

# %%
PREFIX = 'coords_017767_rlx60_'
lengths_1 = helper.length_of_model("./results/data/length/"+PREFIX+"100-350.txt", display=False, totaltime=100)
lengths_2 = helper.length_of_model("./results/data/length/"+PREFIX+"350-600.txt", display=False, totaltime=100)
lengths = lengths_1 + lengths_2
real_lengths = pd.read_csv("./results/data/length/lengths_Pre_Bisect_40x_4fps_ex3.csv").values
real_lengths = [x*(0.227/40) for x in real_lengths]
real_lengths_filtered = helper.filter_abnormal(real_lengths)
real_lengths_filtered = real_lengths_filtered[1100:3040]
plt.figure(figsize=(20,4))
plt.plot(np.arange(0, 485, 0.25), real_lengths_filtered, linewidth=3, color='r')
plt.plot(np.arange(0, 500, 0.1), lengths, linewidth=3, color='b')
plt.show()
