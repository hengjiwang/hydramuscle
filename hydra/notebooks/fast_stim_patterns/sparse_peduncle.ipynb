# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_ims(filename, vmin, vmax):

    # Read the simulation results
    calcium = pd.read_hdf("./results/data/calcium/" + filename + ".h5")
    calcium = calcium.values.reshape(len(calcium), 60, 60)
    ca_ecto = calcium[:, :30, :]
    ca_ecto.shape

    dt = 0.001
    
    fig = plt.figure(figsize=(20,5))
    moments = [0.01, 0.02, 0.05, 0.1, 0.15, 5.01, 5.02, 5.05, 5.1, 5.15]

    for j, moment in enumerate(moments):
        ax = fig.add_subplot(1, len(moments), j+1)
        index = int(moment / dt)
        im = np.flip(ca_ecto[index].T, 0)
        ax.imshow(im, cmap='hot', vmin=vmin, vmax=vmax)
        ax.set_title(str(moment) + 's')
    plt.show()

# %% [markdown]
# ### num_neurons = 1

# %%
plot_ims("2020-09-20-11-27-35-427444", 0, 1)

# %% [markdown]
# ### num_neurons = 2

# %%
plot_ims("2020-09-20-11-27-36-315878", 0, 1)

# %% [markdown]
# ### num_neurons = 3

# %%
plot_ims("2020-09-20-13-04-17-864066", 0, 1)

# %% [markdown]
# ### num_neurons = 4

# %%
plot_ims("2020-09-20-13-04-18-498055", 0, 1)

# %% [markdown]
# ### num_neurons = 5

# %%
plot_ims("2020-09-20-11-27-37-502716", 0, 1)

# %% [markdown]
# ### num_neurons = 10

# %%
plot_ims("2020-09-20-11-27-39-100476", 0, 1)

# %% [markdown]
# ### num_neurons = 20

# %%
plot_ims("2020-09-20-11-27-42-870731", 0, 1)
