# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.abspath(''), '..')))

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import hydramuscle.utils.utils as utils

# %%
lengths_1 = utils.length_of_model("./results/data/length/coords_chalf_005.txt", display=False)
lengths_2 = utils.length_of_model("./results/data/length/coords_chalf_01.txt", display=False)
lengths_3 = utils.length_of_model("./results/data/length/coords_k7endo_0015.txt", display=False)
lengths_4 = utils.length_of_model("./results/data/length/coords_chalf_02.txt", display=False)
lengths_5 = utils.length_of_model("./results/data/length/coords_chalf_05.txt", display=False)
lengths_6 = utils.length_of_model("./results/data/length/coords_chalf_1.txt", display=False)
lengths_7 = utils.length_of_model("./results/data/length/coords_passive.txt", display=False)

# %%
plt.figure(figsize=(10,5))
time_axis = np.arange(0, 100.1, 0.1)
plt.plot(time_axis, lengths_1, linewidth=3, label='$c_{half}$(endo)=0.05')
plt.plot(time_axis, lengths_2, linewidth=3, label='$c_{half}$(endo)=0.1')
plt.plot(time_axis, lengths_3, linewidth=3, label='$c_{half}$(endo)=0.15')
plt.plot(time_axis, lengths_4, linewidth=3, label='$c_{half}$(endo)=0.2')
plt.plot(time_axis, lengths_5, linewidth=3, label='$c_{half}$(endo)=0.5')
plt.plot(time_axis, lengths_6, linewidth=3, label='$c_{half}$(endo)=1.0')
plt.plot(time_axis, lengths_7, linewidth=3, label='$c_{half}$(endo)=0.5, k7(endo)=0.15', linestyle='--', color='k')
plt.legend()
plt.grid()
plt.xlabel('time(s)')
plt.ylabel('length(mm)')
plt.show()
