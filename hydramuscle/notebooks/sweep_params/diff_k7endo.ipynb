# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

import hydramuscle.utils.utils as utils

# %%
lengths_1 = utils.length_of_model("../../results/data/length/coords_k7_endo_0005.txt", display=False)
# lengths_2 = utils.length_of_model("../../results/data/length/coords_k7endo_01.txt", display=False)
lengths_3 = utils.length_of_model("../../results/data/length/coords_k7_endo_002.txt", display=False)
lengths_4 = utils.length_of_model("../../results/data/length/coords_k7_endo_005.txt", display=False)
# # lengths_5 = utils.length_of_model("../../results/data/length/coords_k7endo_0075.txt", display=False)
# lengths_6 = utils.length_of_model("../../results/data/length/coords_k7endo_003.txt", display=False)
lengths_7 = utils.length_of_model("../../results/data/length/coords_k7_endo_001.txt", display=False)
# lengths_8 = utils.length_of_model("../../results/data/length/coords_k7endo_015.txt", display=False)
lengths_9 = utils.length_of_model("../../results/data/length/coords_k7_endo_02.txt", display=False)

# %%
start = 0
end = 990

plt.figure(figsize=(10,5))
time_axis = np.arange(start, end * 0.1, 0.1)
plt.plot(time_axis, lengths_1[start : end], linewidth=3, label='k7(endo)=0.005')
plt.plot(time_axis, lengths_7[start : end], linewidth=3, label='k7(endo)=0.01')
plt.plot(time_axis, lengths_3[start : end], linewidth=3, label='k7(endo)=0.02')
# plt.plot(time_axis, lengths_6, linewidth=3, label='k7(endo)=0.03')
plt.plot(time_axis, lengths_4[start : end], linewidth=3, label='k7(endo)=0.05')
# plt.plot(time_axis, lengths_5, linewidth=3, label='k7(endo)=0.075')
plt.plot(time_axis, lengths_9[start : end], linewidth=3, label='k7(endo)=0.1')
# plt.plot(time_axis, lengths_8, linewidth=3, label='k7(endo)=0.15')
plt.grid()
plt.legend()
plt.xlabel('time(s)')
plt.ylabel('length(mm)')
plt.show()
