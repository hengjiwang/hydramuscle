# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_ims(filename, vmin=0, vmax=1, moments=[0.01, 0.02, 0.05, 0.1, 0.15, 5.01, 5.02, 5.05, 5.1, 5.15]):

    # Read the simulation results
    calcium = pd.read_hdf("../../results/data/calcium/" + filename + ".h5")
    calcium = calcium.values.reshape(len(calcium), 60, 60)
    ca_ecto = calcium[:, :30, :]
    ca_ecto.shape

    dt = 0.001
    
    fig = plt.figure(figsize=(20,5))

    for j, moment in enumerate(moments):
        ax = fig.add_subplot(1, len(moments), j+1)
        index = int(moment / dt)
        im = np.flip(ca_ecto[index].T, 0)
        ax.imshow(im, cmap='hot', vmin=vmin, vmax=vmax)
        ax.set_title(str(moment) + 's')
    plt.show()
    
    return ca_ecto

# %%
# num_neurons = 5
ca_5 = plot_ims("2020-09-20-13-56-52-417508")

# %%
# num_neurons = 10
ca_10 = plot_ims("2020-09-20-13-56-53-676165")

# %%
# num_neurons = 100
ca_50 = plot_ims("2020-09-20-14-00-36-631882")

# %%
# num_neurons = 100
ca_100 = plot_ims("2020-09-20-13-56-53-798711")
