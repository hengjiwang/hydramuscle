# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
force = pd.read_csv('save/data/fluorescence_2d_diff_endo_freq.csv')

# %%
force.shape
# Out:
# (20000, 100)

# %%
f_mean = np.mean(force,1)

# %%
plt.plot(f_mean)
