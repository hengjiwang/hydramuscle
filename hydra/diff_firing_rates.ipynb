# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.abspath(''), '..')))

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import hydra.model.helper as helper

# %%
lengths=[]
for j in range(1, 6):
    lengths.append(helper.length_of_model("./results/data/length/coords_isi" + str(j) + ".txt", display=False))

# %%
plt.figure(figsize=(20,5))
timeaxis = np.arange(0, 100.1, 0.1)
for j, length in enumerate(lengths):
    plt.plot(timeaxis, length, linewidth=3, label='ISI=' + str(j+1) + 's')
#     minval = min(length)
#     plt.plot(timeaxis, [x - minval for x in length], label='ISI=' + str(j+1) + 's')
plt.legend()
plt.xlabel('time(s)')
plt.ylabel('length(mm)')
plt.grid()
plt.show()
